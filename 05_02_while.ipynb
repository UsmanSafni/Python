# %% [markdown]
# <a href="https://colab.research.google.com/github/UsmanSafni/Python/blob/main/05_02_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

# %% [markdown]
# ## While loops

# %%
datetime.now().second
# Out:
# 30

# %%
wait_until = datetime.now().second + 2

while datetime.now().second != wait_until:
    print('Still waiting!')

print(f'We are at {wait_until} seconds!')
# Out:
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# ...
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# Still waiting!
# We are at 11 seconds!

# %%
wait_until = datetime.now().second + 2

while datetime.now().second != wait_until:
    1 + 1

print(f'We are at {wait_until} seconds!')
# Out:
# We are at 38 seconds!

# %% [markdown]
# ### Pass

# %%
wait_until = datetime.now().second + 2

while datetime.now().second != wait_until:
    pass

print(f'We are at {wait_until} seconds!')
# Out:
# We are at 51 seconds!

# %% [markdown]
# ### Break

# %%
wait_until = datetime.now().second + 2

while True:
    if datetime.now().second == wait_until:
        print(f'We are at {wait_until} seconds!')
        break
# Out:
# We are at 5 seconds!

# %%
wait_until = datetime.now().second + 2

while True:
    while datetime.now().second == wait_until:
        print(f'We are at {wait_until} seconds!')
        break
# Out:
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# ...
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# We are at 14 seconds!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <module>
#       1 wait_until = datetime.now().second + 2
#       3 while True:
# ----> 4     while datetime.now().second == wait_until:
#       5         print(f'We are at {wait_until} seconds!')
#       6         break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Continue

# %%
wait_until = datetime.now().second + 2

while datetime.now().second != wait_until:
    continue
    print('Still waiting!')


print(f'We are at {wait_until} seconds!')
# Out:
# We are at 14 seconds!

# %%
wait_until = datetime.now().second + 2

while True:
    if datetime.now().second < wait_until:
        continue
    break


print(f'We are at {wait_until} seconds!')
# Out:
# We are at 9 seconds!
